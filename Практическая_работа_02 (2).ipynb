# %% [markdown]
# # Лабораторная работа 2. Управление ходом выполнения программы

# %% [markdown]
# Понкратов Владимир Александрович ИНБ-б-о-26-2

# %% [markdown]
# ## Задание

# %% [markdown]
# Необходимо вычислить значение выражения:
# $$Z=\frac{Y^2\cdot X}{2}-\frac{Y^2\cdot X^4}{4}+\frac{X^4\cdot Y^6}{6}-\frac{X^8\cdot Y^6}{8}+...$$
# Для каждой переменной необходимо вывести ее значение и тип.

# %% [markdown]
# ## Анализ выражения и определение переменных

# %% [markdown]
# Проанализируем выражение и определим переменные, которые потребуются для выполнения задания. Независимые переменные: $X$. Переменная, которая должна быть вычислена на основе независимых: $Z, Y$.
#
# Следует обратить внимание, что в выражении неизвестное число слагаемых, поэтому необходимо ввести переменную $N$ для представления количества слагаемых.
#
# Обратите внимание, что знаки слагаемых чередуются, а степени числителя и множетели знаменателя привязаны к порядковому номеру слагаемого.

# %% [markdown]
# ## Вычисление выражение, печать результатов

# %% [markdown]
# Код для вычисления значения выражения $Z$:

# %%
X = 2
N = 10
Z = 0
for i in range(1, N+1):
  chisl = X**(i-1)
  znam = i * (i+1)
  if i%2==1:
    Z += chisl / znam
  else:
    Z -= chisl/znam
print(Z)
# Out:
# -2.573593073593073

# %% [markdown]
# Решите пример в соответствии с индивидуальным заданием

# %%
# Здесь код индивидуального задания...
X = 3
Y = 4
N = 12
Z = 0
for i in range(1, N+1):
  chisl = X**(i-1)
  chisl = Y**(i-1)
  znam = i * (i+1)
  if i%2==1:
    Z += chisl / znam
  else:
    Z -= chisl/znam
print(Z)
# Out:
# -20770.04967254967

# %% [markdown]
# # Ответы на вопросы
# 1)
# Переменная в Python - это именованная ссылка на объект в памяти. Проще говоря, это «ярлык» (имя), который указывает на какое‑то значение.
# 2)
# Недопустимы:
# 99bottles - имя переменной не может начинаться с цифры. В Python имена должны начинаться с буквы или символа подчёркивания (_).
# r&d - в имени переменной нельзя использовать спецсимволы, кроме подчёркивания. Символ & недопустим.
# Допустимы:
#
# july2009 - начинается с буквы, содержит буквы и цифры: всё по правилам.
# theSalesFigureForFiscalYear - допустимое имя (стиль camelCase разрешён, хоть чаще в Python используют snake_case).
# grade_report - допустимо: используется подчёркивание, это стандартный стиль именования в Python.
# 3)
# Нет, это разные имена.
# Python - регистрозависимый язык: Sales и sales - это две разные переменные, потому что заглавные и строчные буквы различаются.
# 4)
# В Python оператор присваивания работает так: слева должно быть имя переменной, справа - выражение (значение, другая переменная и т. д.).
# Конструкция 72 = amount пытается присвоить значение переменной amount числу 72, а числа не могут быть «приёмниками» присваивания: они не являются именами переменных. Это вызовет ошибку SyntaxError.
# 5)
# val = 99
# print('Значение равняется', val)
#  Вывод: Значение равняется 99
# 6)
# Типы данных после исполнения:
# value1 → int (целое число)
# value2 → float (число с плавающей точкой)
# value3 → float (даже если значение «похоже на целое», наличие точки делает его float)
# value4 → int
# value5 → str (строка)
# 7)
# Вывод:
# text
# 0
# Почему: переменная my_value сначала получает значение 99, а потом его перезаписывают значением 0. В итоге при вызове print выводится последнееприсвоенное значение.
# 8)
# for x in range(6):
#     print('Обожаю эту программу!')
# 9)
# 0
# 1
# 2
# 3
# 4
# 5
# 10)
# 2
# 3
# 4
# 5
# 11)
# 0
# 100
# 200
# 300
# 400
# 500
# 12)
# 10
# 9
# 8
# 7
# 6
# 13)
# Накопитель (аккумулятор) - это переменная, которая накапливает какое‑то итоговое значение в процессе цикла: сумму, произведение, конкатенацию строк
# 14)
# Да, следует.
# Почему:
# Накопитель должен иметь начальное значение, чтобы на первой итерации цикла можно было корректно выполнить операцию (например, сложение).
# Если не инициализировать, возникнет ошибка NameError, потому что Python попытается использовать переменную до её создания.
# Начальное значение зависит от операции: для суммы это обычно 0, для произведения - 1, для конкатенации строк - пустая строка
# 15)
# 15
# 16)
# 15 5
# 17)
# quantity += 1
# days_left -= 5
# price *= 10
# price /= 2
# 18)
# client_surname = input("Введите фамилию клиента: ")
# 19)
# weekly_sales = float(input("Введите объём продаж за неделю: "))
# 20)
# Бесконечный цикл - это цикл, который никогда не завершается сам по себе, потому что его условие выхода всегда истинно. Такие циклы используют, когда нужно постоянно ожидать события, обрабатывать поток данных и т. п., но в них обязательно должен быть механизм выхода (например, через break при каком‑то условии).
